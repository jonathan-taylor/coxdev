# %%
import numpy as np
import pandas as pd

from coxdev import _cox_dev
from coxdev import _preprocess
from coxdev import CoxDeviance

# %% [markdown]
# # A small dataset (with ties)
#
# - Event times (or "stop" times) $t_i$.
#
# - Start times: $s_i$.

# %%
data_df = pd.read_csv('dataset.csv', index_col='index')[:20]
data_df
n = data_df.shape[0]

# %% [markdown]
# ## Key sequences
#
# We will jointly sort `start` and `event` by stacking the times into
# a data frame with 60 rows instead of 30.
#
# We will sort this on `(time, status, is_start)` with `status==1` occurring before
# `status==0`.

# %%
stacked_df = pd.DataFrame({'time':np.hstack([data_df['start'], data_df['event']]),
                           'status':np.hstack([np.zeros_like(data_df['start']), 
                                               data_df['status']]),
                           'is_start':np.hstack([np.ones(n, int), np.zeros(n, int)]),
                           'index':np.hstack([np.arange(n), np.arange(n)])})
stacked_df
# Out:
#     time  status  is_start  index
# 0      1       0         1      0
# 1      0       0         1      1
# 2      1       0         1      2
# 3      2       0         1      3
# 4      5       0         1      4
# 5      5       0         1      5
# 6      1       0         1      6
# 7      2       0         1      7
# 8      3       0         1      8
# 9      5       0         1      9
# 10     0       0         1     10
# 11     4       0         1     11
# 12     5       0         1     12
# 13     5       0         1     13
# 14     1       0         1     14
# 15     0       0         1     15
# 16     3       0         1     16
# 17     0       0         1     17
# 18     0       0         1     18
# 19     0       0         1     19
# 20     4       0         0      0
# 21     3       0         0      1
# 22     3       0         0      2
# 23     6       1         0      3
# 24     7       1         0      4
# 25     8       1         0      5
# 26     5       0         0      6
# 27     6       1         0      7
# 28     7       1         0      8
# 29    10       1         0      9
# 30     2       1         0     10
# 31     6       1         0     11
# 32     7       0         0     12
# 33     9       0         0     13
# 34     4       0         0     14
# 35     2       1         0     15
# 36     7       0         0     16
# 37     5       1         0     17
# 38     5       1         0     18
# 39     3       0         0     19

# %% [markdown]
# From this joint sort we will define several key sequences of length 30.
#
# - `event_order`: sorts event times into increasing order (according to this joint sort)
# - `start_order`: sorts start times into increasing order (according to this joint sort)
# - `first`: for a failure time, which may have ties, this is the first entry of `event_order` in this set of ties -- the entries of `first` that are not failure times are not used, but they are defined consistently in that no ties of non-failure times are material to the computations.
# - `last`: analogous to `first` but the last time
# - `event_map`: for the $i$-th event time, this is the number of start times stricly less than this event time: $\text{event\_map}[i] = \# \{j: s_j < t_i\}$.
# - `start_map`: for the $i$-th start time, this is the number of event times less than or equal to $s_i$:
#   $\text{start\_map}[i] = \# \{j: t_j \leq s_i\}$.
#
# **These sequences are computed once.**

# %% [markdown]
# ### Computing the key sequences
#
# We sort the stacked data frame, placing "failures" (`status==1`) in front, and `start` times following `event` times.
#
# - This sorted data frame makes it easy to compute `start_order` and `event_order`.
# - Computing `first` requires keeping track of successive `event` times that have `status==1`, continuing to append a current beginning of the tie sequence until a change is detected.
# - Computing `event_map` and `start_map` requires keeping track of the current number of events (or starts) and appending this to `start_map` or `event_map`. This will yield `start_map` (in start order) and `event_map` (in event order). These can reordered to the original index. Later, we will set everything to event order.

# %%
sorted_df = stacked_df.sort_values(by=['time', 'status', 'is_start'], ascending=[True,False,True])
sorted_df
# Out:
#     time  status  is_start  index
# 1      0       0         1      1
# 10     0       0         1     10
# 15     0       0         1     15
# 17     0       0         1     17
# 18     0       0         1     18
# 19     0       0         1     19
# 0      1       0         1      0
# 2      1       0         1      2
# 6      1       0         1      6
# 14     1       0         1     14
# 30     2       1         0     10
# 35     2       1         0     15
# 3      2       0         1      3
# 7      2       0         1      7
# 21     3       0         0      1
# 22     3       0         0      2
# 39     3       0         0     19
# 8      3       0         1      8
# 16     3       0         1     16
# 20     4       0         0      0
# 34     4       0         0     14
# 11     4       0         1     11
# 37     5       1         0     17
# 38     5       1         0     18
# 26     5       0         0      6
# 4      5       0         1      4
# 5      5       0         1      5
# 9      5       0         1      9
# 12     5       0         1     12
# 13     5       0         1     13
# 23     6       1         0      3
# 27     6       1         0      7
# 31     6       1         0     11
# 24     7       1         0      4
# 28     7       1         0      8
# 32     7       0         0     12
# 36     7       0         0     16
# 25     8       1         0      5
# 33     9       0         0     13
# 29    10       1         0      9

# %%
def sort_start_event(original_df, sorted_df):
    event_count, start_count = 0, 0
    event_order, start_order = [], []
    start_map, event_map = [], []
    first = []
    event_idx = []
    last_row = None
    which_event = -1
    first_event = -1
    num_successive_event = 1
    ties = {}    
    for _r in range(sorted_df.shape[0]):
        row = sorted_df.iloc[_r]
        if row['is_start'] == 1: # a start time
            start_order.append(row['index'])
            start_map.append(event_count)
            start_count += 1
        else: # an event / stop time
            if row['status'] == 1:
                # if it's an event and the time is same as last row 
                # it is the same event
                # else it's the next "which_event"
                
                if (last_row is not None and 
                    row['time'] != last_row['time']): # index of next `status==1`
                    first_event += num_successive_event
                    num_successive_event = 1
                    which_event += 1
                else:
                    num_successive_event += 1
                    
                first.append(first_event)
            else:
                first_event += num_successive_event
                num_successive_event = 1
                first.append(first_event) # this event time was not an failure time

            event_map.append(start_count)
            event_order.append(row['index'])
            event_count += 1
        last_row = row

    first = np.array(first)
    start_order = np.array(start_order).astype(int)
    event_order = np.array(event_order).astype(int)
    start_map = np.array(start_map)
    event_map = np.array(event_map)

    # reset start_map to original order
    start_map_cp = start_map.copy()
    start_map[start_order] = start_map_cp

    status_event = np.asarray(original_df['status'])[event_order]
    preprocessed_df = pd.DataFrame({'status':status_event,
                                    'first':first,
                                    'start_map':start_map[event_order].astype(int), 
                                    'event_map':event_map.astype(int) # already in event order
                                    }, index=event_order)
    print(preprocessed_df.index)

    # compute `last`
    
    last = []
    last_event = n-1
    for i, f in enumerate(preprocessed_df['first'][::-1]):
        last.append(last_event)
        # immediately following a last event, `first` will agree with np.arange
        if f - (n - 1 - i) == 0:
            last_event = f - 1        

    preprocessed_df.insert(2, 'last', last[::-1])
    

    return preprocessed_df, event_order, start_order

# %%
(preproc, 
 event_order, 
 start_order) = sort_start_event(data_df, sorted_df)
preproc # note that preproc.index == event_order
# Out:
# Int64Index([10, 15, 1, 2, 19, 0, 14, 17, 18, 6, 3, 7, 11, 4, 8, 12, 16, 5, 13,
#             9],
#            dtype='int64')
#     status  first  last  start_map  event_map
# 10       1      0     1          0         10
# 15       1      0     1          0         10
# 1        0      2     2          0         12
# 2        0      3     3          0         12
# 19       0      4     4          0         12
# 0        0      5     5          0         14
# 14       0      6     6          0         14
# 17       1      7     8          0         15
# 18       1      7     8          0         15
# 6        0      9     9          0         15
# 3        1     10    12          2         20
# 7        1     10    12          2         20
# 11       1     10    12          7         20
# 4        1     13    14         10         20
# 8        1     13    14          5         20
# 12       0     15    15         10         20
# 16       0     16    16          5         20
# 5        1     17    17         10         20
# 13       0     18    18         10         20
# 9        1     19    19         10         20

# %% [markdown]
# Let's add the sorted `event`, `start` and `status` so we can go through some of these
# calculations.

# %%
preproc['event'] = data_df['event'][event_order]
preproc['start'] = data_df['start'][event_order]
preproc
# Out:
#     status  first  last  start_map  event_map  event  start
# 10       1      0     1          0         10      2      0
# 15       1      0     1          0         10      2      0
# 1        0      2     2          0         12      3      0
# 2        0      3     3          0         12      3      1
# 19       0      4     4          0         12      3      0
# 0        0      5     5          0         14      4      1
# 14       0      6     6          0         14      4      1
# 17       1      7     8          0         15      5      0
# 18       1      7     8          0         15      5      0
# 6        0      9     9          0         15      5      1
# 3        1     10    12          2         20      6      2
# 7        1     10    12          2         20      6      2
# 11       1     10    12          7         20      6      4
# 4        1     13    14         10         20      7      5
# 8        1     13    14          5         20      7      3
# 12       0     15    15         10         20      7      5
# 16       0     16    16          5         20      7      3
# 5        1     17    17         10         20      8      5
# 13       0     18    18         10         20      9      5
# 9        1     19    19         10         20     10      5

# %% [markdown]
# Let's look at row with index `11` above. The value of `7` for `start_map` means that this individual's `start` time was
# such that they were not in the risk set for the first 7 event times. Indeed, the `start` time is `4` and there are 7 event times less than or equal to 4.
#
# The value of `event_map` is 20. This means there were 20 start times less than the event time which is `6`.

# %%
(data_df['start'] < 6).sum()
# Out:
# 20

# %% [markdown]
# # Evaluation
#
# ## Saturated log-likelihood
#
# First, let's compute the saturated log-likelihood. This is also a pre-processing step.

# %%
sat_df = preproc[['first', 'status']].copy() # in event order
sat_df['sample_weight'] = data_df['weight'][event_order]
loglik_sat = 0
for _, df in sat_df[['first', 'status', 'sample_weight']].groupby('first'):
    if df['status'].sum() > 0:
        W = (df['sample_weight'] * df['status']).sum()
        loglik_sat -= W * np.log(W)

# %% [markdown]
# ## Efron's tie breaking method
#
# For this, we need yet another array of shape `(n,)`. This vector can be
# computed without `eta`. When there are no ties, this vector is identically 0.

# %%
den = preproc['last'] + 1 - preproc['first']
preproc['scaling'] = (np.arange(n) - preproc['first']) / den

# %% [markdown]
# The columns in `preproc` are:

# %%
preproc.columns
# Out:
# Index(['status', 'first', 'last', 'start_map', 'event_map', 'event', 'start',
#        'scaling'],
#       dtype='object')

# %% [markdown]
# The data frame `preproc` can be computed without reference to `eta`. Its columns
# will be the arguments to the core `C` computation.

# %% [markdown]
# With all of the above preprocessing done, we can now define the relevant
# reversed cumsums in the risk sum: `E` for event, `S` for start and `M` for (scaled) mean:
# $$
# \begin{aligned}
# E_i(\eta) &= \sum_{j:j \geq i} w_j e^{\eta_j} \\
# &= \sum_{j:t_j \geq t_i} w_j e^{\eta_j} \\
# S_i(\eta) &= \sum_{j: s_j > t_i} w_j e^{\eta_j} \\
# M_i(\eta) &= \text{scaling}(i)  \cdot \left(E_{\text{first}(i)}(\eta) - E_{\text{last}(i)+1}(\eta)\right) \\
# &\overset{\text{def}}{=} \sigma_E(i)  \cdot \left(E_{\text{first}(i)}(\eta) - E_{\text{last}(i)+1}(\eta)\right).
# \end{aligned}
# $$
# The risk sums for start / event data with Efron's tie-breaking are
# $$
# R_i(\eta) = E_{\text{first}(i)}(\eta) - S_i(\eta) - M_i(\eta).
# $$
#
# Introducing indicators $\delta_S$ for whether start times are present (otherwise equal to $-\infty)$ and
# $\delta_E$ for whether we use Efron's tie correction, we can include all 4 cases with the risk sum
# $$
# R_i(\eta) = E_i(\eta) - \delta_S \cdot S_i(\eta) - \delta_E \cdot M_i(\eta).
# $$
#
# The log-likelihood (in all four cases) is defined to be
# $$
# \ell(\eta) = \sum_i w_i d_i \left(\eta_i - \log(R_i(\eta))\right)
# $$

# %% [markdown]
# The following derivatives are useful for computing the gradient and Hessian of the log-likelihood:
# $$
# \begin{aligned}
# \frac{\partial}{\partial \eta_k} E_i(\eta) &= w_k e^{\eta_k} \cdot 1_{\{k \geq \text{first}(i)\}} \\
# &= w_k e^{\eta_k} \cdot 1_{\{i \leq \text{last}(k)\}} \\
# \frac{\partial}{\partial \eta_k} S_i(\eta) &= w_k e^{\eta_k}  \cdot 1_{\{s_k > t_i\}} \\
# &= w_k e^{\eta_k} \cdot 1_{\{i < \text{start\_map}(k)\}} \\
# &= w_k e^{\eta_k} \cdot 1_{\{i \leq \text{start\_map}(k)-1\}} \\
# \frac{\partial}{\partial \eta_k} M_i(\eta) &= w_k e^{\eta_k} \cdot \text{scaling}_i \cdot 1_{[\text{first}(i), \text{last}(i)]}(k) \\
# &\overset{\text{def}}{=} w_k e^{\eta_k} \cdot \sigma_E(i) \cdot \left( 1_{\{i \leq  \text{last}(k)\}} - 1_{\{i \leq \text{first}(k)-1\}}\right)
# \end{aligned}
# $$

# %% [markdown]
# ### Gradient
#
# Let's compute the derivative
# $$
# \begin{aligned}
# \frac{\partial}{\partial \eta_k} \ell(\eta) &=
# w_k d_k - w_k e^{\eta_k} \cdot \sum_{i=1}^n w_i d_i \cdot \frac{1_{\{i \leq \text{last}(k)\}} - \delta_S \cdot 1_{\{i \leq \text{start\_map}(k)-1 \}}
# - \delta_E \cdot \sigma_E(i) \cdot \left( 1_{\{i \leq \text{last}(k)\}} - 1_{\{i \leq \text{first}(k)-1\}}\right)}{R_i(\eta)}
# \end{aligned}
# $$
#
# We see this can be expressed cumsums of the sequences
# $$
# \frac{w_i d_i}{R_i(\eta)}, \qquad \frac{w_i d_i \sigma_E(i)}{R_i(\eta)}.
# $$
#
# Define
# $$
# {\cal C}_{rs}(\eta)[i] = \sum_{j=1}^i \frac{w_i d_i \sigma_E(i)^s}{R_i(\eta)^r}.
# $$

# %% [markdown]
# Our derivative above is
# $$
# w_k d_k - w_k e^{\eta_k} \left({\cal C}_{10}(\eta)[\text{last}(k)] - \delta_S \cdot {\cal C}_{10}(\eta)[\text{start\_map}(k)-1] - \delta_E \cdot \left({\cal C}_{11}(\eta)[\text{last}(k)] - {\cal C}_{11}(\eta)[\text{first}(k)-1] \right) \right)
# $$

# %% [markdown]
# ### Hessian
#
# Let's compute the second
# derivative
# $$
# \frac{\partial^2}{\partial \eta_l \eta_k} \ell(\eta)
# $$
# consists of two terms. The first is the diagonal
# $$
# T_{1,kl}(\eta) = - \delta_{lk} w_ke^{\eta_k} \left({\cal C}_{10}(\eta)[\text{last}(k)] - \delta_S \cdot {\cal C}_{10}(\eta)[\text{start\_map}(k)-1] - \delta_E \cdot \left({\cal C}_{11}(\eta)[\text{last}(k)] - {\cal C}_{11}(\eta)[\text{first}(k)-1] \right) \right)
# $$

# %% [markdown]
# The second is
# $$
# \begin{aligned}
# T_{2,kl}(\eta) &= \sum_{i=1}^n w_i d_i \biggl[\frac{\left(1_{\{i \leq \text{last}(k)\}} - \delta_S \cdot 1_{\{i \leq \text{start\_map}(k) -1\}}
# - \delta_E \cdot \sigma_E(i) \cdot \left( 1_{\{i \leq \text{last}(k)\}} - 1_{\{i \leq \text{first}(k)-1\}}\right)\right) }{R_i(\eta)} \\
#  & \qquad \qquad \times \frac{\left(1_{\{i \leq \text{last}(l)\}} - \delta_S \cdot 1_{\{i \leq \text{start\_map}(l) -1\}}
# - \delta_E \cdot \sigma_E(i) \cdot \left( 1_{\{i \leq \text{last}(l)\}} - 1_{\{i \leq \text{first}(l)-1\}}\right)\right) }{R_i(\eta)}
#   \biggr]
# \end{aligned}
# $$

# %% [markdown]
# Without belaboring the expansion just yet, it is clear that this can be expressed in terms of
# $$
# \left({\cal C}_{rs}(\eta)\right)_{1 \leq r \leq 2, 1 \leq s \leq r}.
# $$
#
# ### Diagonal of Hessian
#
# The diagonal terms $T_{2,kk}(\eta)$ are
# $$
# \begin{aligned}
# T_{2,kk}(\eta) &= \sum_{i=1}^n w_i d_i \frac{\left(1_{\{i \leq \text{last}(k)\}} - \delta_S \cdot 1_{\{i \leq \text{start\_map}(k)-1 \}}
# - \delta_E \cdot \sigma_E(i) \cdot \left( 1_{\{i \leq \text{last}(k)\}} - 1_{\{i \leq \text{first}(k)-1\}}\right)\right)^2 }{R_i(\eta)^2}
# \end{aligned}
# $$

# %% [markdown]
# #### Expansion
#
# Let's expand the numerator in $T_{2,kl}(\eta)$ which will tell us which indices of the
# relevant cumsums to use.
# $$
# \begin{aligned}
# N_{kl} &= \left(1_{\{i \leq \text{last}(k)\}} - \delta_S \cdot 1_{\{i \leq \text{start\_map}(k)-1 \}}
# - \delta_E \cdot \sigma_E(i) \cdot \left( 1_{\{i \leq \text{last}(k)\}} - 1_{\{i \leq \text{first}(k)-1\}}\right)\right) \\
# & \qquad \times \left(1_{\{i \leq \text{last}(l)\}} - \delta_S \cdot 1_{\{i \leq \text{start\_map}(l)-1 \}}
# - \delta_E \cdot \sigma_E(i) \cdot \left( 1_{\{i \leq \text{last}(l)\}} - 1_{\{i \leq \text{first}(l)-1\}}\right)\right)
# \end{aligned}
# $$
#
# It will be handy to use a symbolic manipulation tool for this as there are many terms.

# %%
from sympy import Symbol, Function, simplify, expand

last_ = Function('last')
start_ = Function('start')
first_ = Function('first')
k = Symbol('k')
l = Symbol('l')
s_E = Symbol('sigma_E')
d_E = Symbol('delta_E')
d_S = Symbol('delta_S')

E_k = last_(k) - d_S * start_(k-1) - d_E * s_E * (last_(k) - first_(k-1))

# %%
diag_prod = expand(E_k * E_k)
diag_prod.as_ordered_terms()
# Out:
# [delta_E**2*sigma_E**2*first(k - 1)**2,
#  -2*delta_E**2*sigma_E**2*first(k - 1)*last(k),
#  delta_E**2*sigma_E**2*last(k)**2,
#  -2*delta_E*delta_S*sigma_E*first(k - 1)*start(k - 1),
#  2*delta_E*delta_S*sigma_E*last(k)*start(k - 1),
#  2*delta_E*sigma_E*first(k - 1)*last(k),
#  -2*delta_E*sigma_E*last(k)**2,
#  delta_S**2*start(k - 1)**2,
#  -2*delta_S*last(k)*start(k - 1),
#  last(k)**2]

# %% [markdown]
# This list of terms can be used to deduce which ${\cal C}_{rs}(\eta)$ are needed
# to compute the diagonal. Of course we use the logic that `delta_E**2=delta_E`,
# `delta_S**2=delta_S` and whenever we see terms like $\text{last}(k)*\text{first}(k-1)$ or
# similar this becomes
# $$
# 1_{\{i \leq \min(\text{last}(k), \text{first}(k)-1)\}} = 1_{\{i \leq \text{first}(k)-1\}}.
# $$
#
# If we were clever, we could try to take the above symbolic representation and turn it into
# correct LaTeX but it is not too painful to do by hand.

# %% [markdown]
# #### Simplification: right censored with Breslow's method
#
# By setting $\delta_S$ or $\delta_E$ to 0, these expressions symplify considerably.
# Let's try setting $\delta_S=\delta_E=0$. This is right-censored data with Breslow's tie-breaking.
# This has no $\sigma_E$ in it, so we know we only need ${\cal C}_{10}$ and ${\cal C}_{20}$ to compute it.

# %%
diag_prod.subs(d_E,0).subs(d_S,0).as_ordered_terms()
# Out:
# [last(k)**2]

# %% [markdown]
# From this we deduce that the diagonal entries for right-censored data with
# Breslow's tie breaking are:
# $$
# T_{2,kk}(\eta) = {\cal C}_{20}(\eta)[\text{last}(k)]
# $$

# %% [markdown]
# #### Simplification: start times with Breslow's method
#
# Let's do Breslow's tie breaking with start times.

# %%
diag_prod.subs(d_E,0).subs(d_S, 1).as_ordered_terms()
# Out:
# [last(k)**2, -2*last(k)*start(k - 1), start(k - 1)**2]

# %% [markdown]
# As $\text{start}(k) \leq \text{last}(k)$ we see that, in this case
# $$
# T_{2,kk}(\eta) = C_{20}(\eta)[\text{last}(k)] - C_{20}(\eta)[\text{start}(k)-1].
# $$

# %% [markdown]
# #### Simplification: right-censored with Efron's tie-breaking:

# %%
diag_prod.subs(d_S,0).subs(d_E, 1).as_ordered_terms()
# Out:
# [sigma_E**2*first(k - 1)**2,
#  -2*sigma_E**2*first(k - 1)*last(k),
#  sigma_E**2*last(k)**2,
#  2*sigma_E*first(k - 1)*last(k),
#  -2*sigma_E*last(k)**2,
#  last(k)**2]

# %% [markdown]
# This has powers $\sigma_E^{\{0,1,2\}}$ so we will need all 5 ${\cal C}_{rs}$ cumsums to evaluate
# it and the gradient.
# For this case,
# $$
# \begin{aligned}
# T_{2,kk}(\eta) &= {\cal C}_{22}(\eta)[\text{first}(k)-1] \\
# & -2 \cdot {\cal C}_{22}(\eta)[\text{first}(k)-1] \\
# & + {\cal C}_{22}(\eta)[\text{last}(k)] \\
# & + 2 \cdot {\cal C}_{21}(\eta)[\text{first}(k)-1] \\
# & -2 \cdot {\cal C}_{21}(\eta)[\text{last}(k)] \\
# & + {\cal C}_{20}(\eta)[\text{last}(k)] \\
# &= ({\cal C}_{22}(\eta)[\text{last}(k)] - {\cal C}_{22}(\eta)[\text{first}(k)-1]) \\
# & - 2 \cdot ({\cal C}_{21}(\eta)[\text{last}(k)] - {\cal C}_{21}(\eta)[\text{first}(k)-1]) \\
# & + {\cal C}_{20}(\eta)[\text{last}(k)] \\
# \end{aligned}
# $$

# %% [markdown]
# #### General case

# %%
diag_prod.subs(d_S,1).subs(d_E, 1).as_ordered_terms()
# Out:
# [sigma_E**2*first(k - 1)**2,
#  -2*sigma_E**2*first(k - 1)*last(k),
#  sigma_E**2*last(k)**2,
#  2*sigma_E*first(k - 1)*last(k),
#  -2*sigma_E*first(k - 1)*start(k - 1),
#  -2*sigma_E*last(k)**2,
#  2*sigma_E*last(k)*start(k - 1),
#  last(k)**2,
#  -2*last(k)*start(k - 1),
#  start(k - 1)**2]

# %% [markdown]
# This will have a few more terms than previous. Let's just see which they are.

# %%
full = set(diag_prod.subs(d_S,1).subs(d_E, 1).as_ordered_terms())
partial = set(diag_prod.subs(d_S,0).subs(d_E, 1).as_ordered_terms())
assert partial.issubset(full)

# %%
full.difference(partial)
# Out:
# {-2*last(k)*start(k - 1),
#  -2*sigma_E*first(k - 1)*start(k - 1),
#  2*sigma_E*last(k)*start(k - 1),
#  start(k - 1)**2}

# %% [markdown]
# By appending these terms to those above,  and we note  that $\text{start}(k)-1 \leq \text{first}(k)-1$ (Why? Because $s_k$ is strictly less than $t_k$ and $t_{\text{first}(k)-1}$ is the event time immediately preceeding $t_k$.)
# Therefore
# $$
# \begin{aligned}
# T_{2,kk}(\eta)  &= ({\cal C}_{22}(\eta)[\text{last}(k)] - {\cal C}_{22}(\eta)[\text{first}(k)-1]) \\
# & - 2 \cdot ({\cal C}_{21}(\eta)[\text{last}(k)] - {\cal C}_{21}(\eta)[\text{first}(k)-1]) \\
# & + {\cal C}_{20}(\eta)[\text{last}(k)] \\
# & - 2 \cdot {\cal C}_{20}(\eta)[\text{start}(k)-1] \\
# & - 2 \cdot {\cal C}_{21}(\eta)[\text{start}(k)-1] \\
# & + 2 \cdot {\cal C}_{21}(\eta)[\text{start}(k)-1] \\
# & + {\cal C}_{20}(\eta)[\text{start}(k)-1] \\
# &=  ({\cal C}_{22}(\eta)[\text{last}(k)] - {\cal C}_{22}(\eta)[\text{first}(k)-1]) \\
# & - 2 \cdot ({\cal C}_{21}(\eta)[\text{last}(k)] - {\cal C}_{21}(\eta)[\text{first}(k)-1]) \\
# & + {\cal C}_{20}(\eta)[\text{last}(k)] - {\cal C}_{20}(\eta)[\text{start}(k)-1]
# \end{aligned}
# $$

# %%
assert np.all(preproc['start'] <= preproc['first'])

# %% [markdown]
# #### Off-diagonal Hessian entries
#
# We can similarly deduce how to evaluate off-diagonal entries of the Hessian, though
# we have not implemented all of these yet.

# %%
E_l = last_(l) - d_S * start_(l) - d_E * s_E * (last_(l) - first_(l-1))
prod = expand(E_k * E_l)
prod.as_ordered_terms()
# Out:
# [delta_E**2*sigma_E**2*first(k - 1)*first(l - 1),
#  -delta_E**2*sigma_E**2*first(k - 1)*last(l),
#  -delta_E**2*sigma_E**2*first(l - 1)*last(k),
#  delta_E**2*sigma_E**2*last(k)*last(l),
#  -delta_E*delta_S*sigma_E*first(k - 1)*start(l),
#  -delta_E*delta_S*sigma_E*first(l - 1)*start(k - 1),
#  delta_E*delta_S*sigma_E*last(k)*start(l),
#  delta_E*delta_S*sigma_E*last(l)*start(k - 1),
#  delta_E*sigma_E*first(k - 1)*last(l),
#  delta_E*sigma_E*first(l - 1)*last(k),
#  -2*delta_E*sigma_E*last(k)*last(l),
#  delta_S**2*start(l)*start(k - 1),
#  -delta_S*last(k)*start(l),
#  -delta_S*last(l)*start(k - 1),
#  last(k)*last(l)]

# %% [markdown]
# ## Evaluation
# Below is the evaluation in `python` code that is similar to what the `C` code will look like.

# %%
def log_like(eta,           # eta is in native order 
             sample_weight, # sample_weight is in native order
             event_order,   
             start_order,
             status,        # everything below in event order
             event,
             start,
             first,
             last,
             scaling,
             event_map,
             start_map,
             loglik_sat,
             have_start_times=True,
             efron=False):

    # be sure they're arrays so that no weird pandas indexing is used
    eta = np.asarray(eta)
    sample_weight = np.asarray(sample_weight)
    event_order = np.asarray(event_order)   
    start_order = np.asarray(start_order)
    status = np.asarray(status)
    event = np.asarray(event)
    start = np.asarray(start)
    first = np.asarray(first)
    last = np.asarray(last)
    scaling = np.asarray(scaling)
    event_map = np.asarray(event_map)
    start_map = np.asarray(start_map)
    
    _status = (status==1)
    
    eta = eta - eta.mean()
    
    # compute the event ordered reversed cumsum
    eta_event = eta[event_order]
    w_event = sample_weight[event_order]
    exp_eta_w_event = w_event * np.exp(eta_event)
    event_cumsum = np.hstack([np.cumsum(exp_eta_w_event[::-1])[::-1], 0]) # length=n+1 for when last=n-1

    # compute the start oredered reversed cumsum, if necessary
    # then compute the cumsums (or difference of cumsums) for Breslow approximation
    
    if have_start_times:
        exp_eta_w_start = np.hstack([(sample_weight * np.exp(eta))[start_order], 0]) # length=n+1
        start_cumsum = np.cumsum(exp_eta_w_start[::-1])[::-1]  # length=n+1
        risk_sums = event_cumsum[first] - start_cumsum[event_map]
    else:
        risk_sums = event_cumsum[first]
        
    # compute the Efron correction, adjusting risk_sum if necessary
    
    if efron == True:
        # XXXXX is last term handled correctly?
        n = eta.shape[0]
        num = (event_cumsum[first] - 
               event_cumsum[last+1])
        risk_sums -= num * scaling
    
    log_terms = np.log(np.array(risk_sums)) * w_event * _status
    loglik = (w_event * eta_event * _status).sum() - np.sum(log_terms)

    # cumsums for gradient and Hessian
    
    # length of cumsums is n+1
    # 0 is prepended for first(k)-1, start(k)-1 lookups
    # a 1 is added to all indices

    A_10 = _status * w_event / risk_sums
    C_10 = np.hstack([0, np.cumsum(A_10)]) 
    
    A_20 = _status * w_event / risk_sums**2
    C_20 = np.hstack([0, np.cumsum(A_20)]) # length=n+1

    # if there are no ties, scaling should be identically 0
    # don't bother with cumsums below 

    if not efron:
        if have_start_times:
            T_1_term = C_10[last+1] - C_10[start_map]   # +1 for start_map? depends on how  
                                                         # a tie between a start time and an event time
                                                         # if that means the start individual is excluded
                                                         # we should add +1, otherwise there should be
                                                         # no +1 in the [start_map+1] above
            T_2_term = C_20[last+1] - C_20[start_map]
        else:
            T_1_term = C_10[last+1]
            T_2_term = C_20[last+1]
    else:
        # compute the other necessary cumsums
        
        A_11 = _status * w_event * scaling / risk_sums
        C_11 = np.hstack([0, np.cumsum(A_11)]) # length=n+1

        A_21 = _status * w_event * scaling / risk_sums
        C_21 = np.hstack([0, np.cumsum(A_21)]) # length=n+1

        A_22 = _status * w_event * scaling / risk_sums
        C_22 = np.hstack([0, np.cumsum(A_22)]) # length=n+1

        T_1_term = (C_10[last+1] - 
                    (C_11[last+1] - C_11[first]))
        T_2_term = ((C_22[last+1] - C_22[first]) 
                    - 2 * (C_21[last+1] - C_21[first]) + 
                    C_20[last+1])
        if have_start_times:
            T_1_term -= C_10[start_map]
            T_2_term -= C_20[first]
    
    grad = w_event * _status - exp_eta_w_event * T_1_term
    grad_cp = grad.copy()
    grad[event_order] = grad_cp

    # now the diagonal of the Hessian

    diag_hess = exp_eta_w_event**2 * T_2_term - exp_eta_w_event * T_1_term
    diag_hess_cp = diag_hess.copy()
    diag_hess[event_order] = diag_hess_cp

    deviance = 2 * (loglik_sat - loglik)
    return deviance, -2 * grad, -2 * diag_hess

# %%
eta = data_df['eta'] # in native order
print(loglik_sat)
dev, G, H = _cox_dev(eta,
                     data_df['weight'],
                     event_order,
                     start_order,
                     preproc['status'],
                     preproc['event'],
                     preproc['start'],
                     preproc['first'],
                     preproc['last'],
                     preproc['scaling'],
                     preproc['event_map'],
                     preproc['start_map'],
                     loglik_sat,
                     efron=False,
                     have_start_times=True)
# Out:
# -21.747664708385678

# %%
import rpy2
# %load_ext rpy2.ipython
start = data_df['start'].copy()
event = data_df['event'].copy()
status = data_df['status'].copy()
weight = data_df['weight'].copy()
# %R -i start,event,status,eta,weight

# %%
# %%R -o G_R,H_R,D_R
# library(survival)
# library(glmnet)
# Y = Surv(start, event, status)
# D_R = glmnet:::coxnet.deviance3(pred=eta, y=Y, weight=weight, std.weights=FALSE)
# # glmnet computes grad and hessian of the log-likelihood, not deviance
# # need to multiply by -2 to get grad and hessian of deviance
# G_R = glmnet:::coxgrad3(eta, Y, weight, std.weights=FALSE, diag.hessian=TRUE)
# H_R = attr(G_R, 'diag_hessian')
# G_R = -2 * G_R
# H_R = -2 * H_R
# Out:
# Loading required package: Matrix
# Loaded glmnet 4.1-4

# %%
np.fabs(dev - D_R)
# Out:
# array([0.])

# %%
np.linalg.norm(G-G_R)/ np.linalg.norm(G)
# Out:
# 1.5988084839017743e-16

# %%
np.linalg.norm(H-H_R) / np.linalg.norm(H)
# Out:
# 1.132529836387499e-16

# %% [markdown]
# ## Using `CoxDeviance`

# %%
coxdev_ = CoxDeviance(event,
                      status,
                      start=start,
                      tie_breaking='breslow')
dev_, G_, H_ = coxdev_(eta, 
                       weight)

# %%
np.fabs(dev - dev_)
# Out:
# 0.0

# %%
np.linalg.norm(G-G_)/ np.linalg.norm(G)
# Out:
# 0.0

# %%
np.linalg.norm(H-H_) / np.linalg.norm(H)
# Out:
# 0.0

# %% [markdown]
# ## Larger data sets

# %%
ties = True
n = 300
rng = np.random.default_rng(0)
start = rng.integers(0, 10, size=n) 
event = start + rng.integers(0, 10, size=n) + ties + (1 - ties) * rng.standard_exponential(n) * 0.01
status = rng.choice([0,1], size=n, replace=True)
weight = rng.uniform(1, 2, size=n)
eta = rng.standard_normal(n)

# %%
# %%R -i event,status,start,eta,weight -o G_R,H_R,D_R
# library(survival)
# library(glmnet)
# Y = Surv(start, event, status)
# print(length(Y))
# eta = as.numeric(eta)
# weight = as.numeric(weight)
# print(system.time(for (i in 1:20) {c(glmnet:::coxnet.deviance3(pred=eta, y=Y, weight=weight, std.weights=FALSE),
#                     glmnet:::coxgrad3(eta, Y, weight, std.weights=FALSE, diag.hessian=TRUE))}))
# D_R = glmnet:::coxnet.deviance3(pred=eta, y=Y, weight=weight, std.weights=FALSE)
# G_R = glmnet:::coxgrad3(eta, Y, weight, std.weights=FALSE, diag.hessian=TRUE)
# H_R = attr(G_R, 'diag_hessian')
# G_R = -2 * G_R
# H_R = -2 * H_R
# Out:
# [1] 300
#    user  system elapsed
#   0.027   0.000   0.028

# %%
# %%timeit
coxdev_ = CoxDeviance(event,
                      status,
                      start=start,
                      tie_breaking='breslow')
dev_, G_, H_ = coxdev_(eta, 
                       weight)
# Out:
# 27.5 ms ± 346 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
coxdev_ = CoxDeviance(event,
                      status,
                      start=start,
                      tie_breaking='breslow')
dev_, G_, H_ = coxdev_(eta, 
                       weight)

# %%
np.fabs(dev_ - D_R)
# Out:
# array([0.])

# %%
np.linalg.norm(G_-G_R) / np.linalg.norm(G)
# Out:
# 1.2047543964313592e-15

# %%
np.linalg.norm(H_-H_R) / np.linalg.norm(H)
# Out:
# 1.6699045904732747e-15

# %%
# %%prun
coxdev_ = CoxDeviance(event,
                      status,
                      start=start,
                      tie_breaking='breslow')
# Out:
#          159789 function calls (157878 primitive calls) in 0.050 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1200    0.004    0.000    0.006    0.000 numerictypes.py:573(_can_coerce_all)
#       600    0.003    0.000    0.021    0.000 managers.py:1078(fast_xs)
# 31814/31797    0.002    0.000    0.004    0.000 {built-in method builtins.isinstance}
#      1805    0.002    0.000    0.008    0.000 series.py:966(__getitem__)
#      8400    0.002    0.000    0.002    0.000 numerictypes.py:582(<listcomp>)
#       600    0.002    0.000    0.013    0.000 cast.py:1589(find_common_type)
#       611    0.001    0.000    0.030    0.000 frame.py:3703(_ixs)
#         1    0.001    0.001    0.049    0.049 __init__.py:86(_preprocess)
#       600    0.001    0.000    0.035    0.000 indexing.py:1592(_getitem_axis)
# 15864/14006    0.001    0.000    0.002    0.000 {built-in method builtins.len}
#      2420    0.001    0.000    0.002    0.000 indexing.py:2656(check_deprecated_indexers)
#       617    0.001    0.000    0.002    0.000 generic.py:5844(__finalize__)
#      1804    0.001    0.000    0.004    0.000 series.py:1072(_get_value)
#      1204    0.001    0.000    0.002    0.000 common.py:1278(is_bool_dtype)
#      1818    0.001    0.000    0.001    0.000 base.py:3754(get_loc)
#      1232    0.001    0.000    0.003    0.000 generic.py:5904(__setattr__)
#       620    0.001    0.000    0.001    0.000 generic.py:259(__init__)
#      1804    0.001    0.000    0.002    0.000 base.py:5934(_get_values_for_loc)
#      3271    0.001    0.000    0.001    0.000 generic.py:45(_instancecheck)
#       604    0.001    0.000    0.003    0.000 blocks.py:2172(new_block)
#       600    0.001    0.000    0.007    0.000 numerictypes.py:597(find_common_type)
#      3271    0.001    0.000    0.001    0.000 generic.py:40(_check)
#      1825    0.001    0.000    0.001    0.000 managers.py:2069(internal_values)
#       617    0.001    0.000    0.004    0.000 series.py:342(__init__)
#       600    0.001    0.000    0.036    0.000 indexing.py:1059(__getitem__)
#      1220    0.000    0.000    0.001    0.000 construction.py:461(ensure_wrapped_if_datetimelike)
#      1203    0.000    0.000    0.003    0.000 {built-in method builtins.any}
#       608    0.000    0.000    0.001    0.000 blocks.py:2091(maybe_coerce_values)
#       623    0.000    0.000    0.001    0.000 base.py:5304(__getitem__)
#      1262    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#      2423    0.000    0.000    0.001    0.000 common.py:362(apply_if_callable)
#      2411    0.000    0.000    0.000    0.000 blocks.py:827(iget)
#      1821    0.000    0.000    0.002    0.000 {built-in method builtins.all}
#      1825    0.000    0.000    0.001    0.000 series.py:708(_values)
#       611    0.000    0.000    0.001    0.000 blocks.py:2120(get_block_type)
#       630    0.000    0.000    0.001    0.000 series.py:611(name)
#       604    0.000    0.000    0.001    0.000 blocks.py:2186(check_ndim)
#       601    0.000    0.000    0.001    0.000 common.py:96(is_bool_indexer)
#       616    0.000    0.000    0.000    0.000 managers.py:1891(__init__)
#       615    0.000    0.000    0.001    0.000 series.py:661(name)
#      1800    0.000    0.000    0.003    0.000 cast.py:1635(<genexpr>)
#      1200    0.000    0.000    0.001    0.000 managers.py:275(arrays)
#      4834    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#       600    0.000    0.000    0.001    0.000 indexing.py:1539(_validate_integer)
#       622    0.000    0.000    0.000    0.000 generic.py:5888(__getattr__)
#      1818    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#       600    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#      1200    0.000    0.000    0.001    0.000 base.py:163(array)
#      1800    0.000    0.000    0.000    0.000 cast.py:1619(<genexpr>)
#       603    0.000    0.000    0.000    0.000 generic.py:564(_get_axis)
#      1216    0.000    0.000    0.000    0.000 common.py:1556(get_dtype)
#       600    0.000    0.000    0.013    0.000 base.py:210(interleaved_dtype)
#      1230    0.000    0.000    0.000    0.000 common.py:1744(<genexpr>)
#      1249    0.000    0.000    0.000    0.000 base.py:925(__len__)
#       600    0.000    0.000    0.001    0.000 base.py:46(__len__)
#      1200    0.000    0.000    0.001    0.000 cast.py:1628(<genexpr>)
#       615    0.000    0.000    0.001    0.000 common.py:1725(validate_all_hashable)
#       600    0.000    0.000    0.000    0.000 generic.py:4114(_set_is_copy)
#       620    0.000    0.000    0.000    0.000 flags.py:49(__init__)
#       600    0.000    0.000    0.000    0.000 managers.py:1097(<listcomp>)
#      3338    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       606    0.000    0.000    0.000    0.000 common.py:319(is_datetime64_dtype)
#      1200    0.000    0.000    0.000    0.000 cast.py:1630(<genexpr>)
#      1200    0.000    0.000    0.000    0.000 managers.py:287(<listcomp>)
#       600    0.000    0.000    0.000    0.000 numerictypes.py:649(<listcomp>)
#       617    0.000    0.000    0.000    0.000 flags.py:85(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 sorting.py:109(get_group_index)
#       622    0.000    0.000    0.000    0.000 common.py:151(cast_scalar_indexer)
#       628    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#       654    0.000    0.000    0.000    0.000 inference.py:325(is_hashable)
#      1234    0.000    0.000    0.000    0.000 generic.py:353(flags)
#      1818    0.000    0.000    0.000    0.000 base.py:6569(_maybe_cast_indexer)
#      1930    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#      1200    0.000    0.000    0.000    0.000 blocks.py:213(mgr_locs)
#      1817    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#       606    0.000    0.000    0.000    0.000 common.py:393(is_timedelta64_dtype)
#      1829    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#      2423    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       600    0.000    0.000    0.000    0.000 {pandas._libs.lib.dtypes_all_equal}
#       605    0.000    0.000    0.000    0.000 inference.py:188(is_array_like)
#     62/36    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       616    0.000    0.000    0.000    0.000 common.py:1420(is_1d_only_ea_dtype)
#       617    0.000    0.000    0.000    0.000 generic.py:332(attrs)
#       617    0.000    0.000    0.000    0.000 generic.py:550(_get_axis_number)
#       600    0.000    0.000    0.000    0.000 utils.py:66(is_list_like_indexer)
#        11    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#         7    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#     12/10    0.000    0.000    0.001    0.000 base.py:430(__new__)
#         1    0.000    0.000    0.002    0.002 sorting.py:304(lexsort_indexer)
#       604    0.000    0.000    0.000    0.000 managers.py:238(items)
#       600    0.000    0.000    0.000    0.000 indexing.py:139(iloc)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#       618    0.000    0.000    0.000    0.000 managers.py:2433(_using_copy_on_write)
#       616    0.000    0.000    0.000    0.000 managers.py:2009(_block)
#       679    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#       617    0.000    0.000    0.000    0.000 flags.py:53(allows_duplicate_labels)
#        20    0.000    0.000    0.000    0.000 construction.py:493(sanitize_array)
#        19    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       600    0.000    0.000    0.000    0.000 numerictypes.py:650(<listcomp>)
#        13    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.000    0.000 {method 'factorize' of 'pandas._libs.hashtable.Int64HashTable' objects}
#       602    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       623    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#       623    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#       619    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#         3    0.000    0.000    0.001    0.000 categorical.py:368(__init__)
#         6    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'factorize' of 'pandas._libs.hashtable.Float64HashTable' objects}
#         4    0.000    0.000    0.000    0.000 function_base.py:5250(insert)
#        15    0.000    0.000    0.000    0.000 frame.py:3758(__getitem__)
#         3    0.000    0.000    0.000    0.000 managers.py:2305(_stack_arrays)
#         9    0.000    0.000    0.000    0.000 base.py:881(_engine)
#         8    0.000    0.000    0.000    0.000 base.py:708(_with_infer)
#        11    0.000    0.000    0.000    0.000 warnings.py:130(filterwarnings)
#        11    0.000    0.000    0.000    0.000 managers.py:1129(iget)
#        25    0.000    0.000    0.000    0.000 base.py:5254(__contains__)
#         1    0.000    0.000    0.050    0.050 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'increment_above' of 'pandas._libs.internals.BlockPlacement' objects}
#         8    0.000    0.000    0.000    0.000 common.py:235(asarray_tuplesafe)
#         9    0.000    0.000    0.000    0.000 base.py:2381(is_unique)
#         2    0.000    0.000    0.000    0.000 managers.py:2253(_form_blocks)
#        11    0.000    0.000    0.000    0.000 types.py:176(__get__)
#         1    0.000    0.000    0.050    0.050 __init__.py:15(__post_init__)
#         6    0.000    0.000    0.000    0.000 dtypes.py:507(validate_categories)
#     61/53    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#        19    0.000    0.000    0.000    0.000 construction.py:744(_try_cast)
#        17    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#        17    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#         5    0.000    0.000    0.000    0.000 take.py:120(_take_nd_ndarray)
#         4    0.000    0.000    0.001    0.000 managers.py:1394(insert)
#        43    0.000    0.000    0.000    0.000 common.py:1591(_is_dtype_type)
#         4    0.000    0.000    0.000    0.000 base.py:6844(insert)
#        15    0.000    0.000    0.000    0.000 frame.py:4274(_get_item_cache)
#        12    0.000    0.000    0.000    0.000 base.py:690(_simple_new)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#         3    0.000    0.000    0.000    0.000 sorting.py:152(maybe_lift)
#         4    0.000    0.000    0.000    0.000 base.py:1316(_arith_method)
#         3    0.000    0.000    0.001    0.000 algorithms.py:593(factorize)
#         3    0.000    0.000    0.000    0.000 algorithms.py:1795(safe_sort)
#         3    0.000    0.000    0.000    0.000 algorithms.py:530(factorize_array)
#        10    0.000    0.000    0.000    0.000 base.py:588(_dtype_to_subclass)
#        11    0.000    0.000    0.000    0.000 frame.py:4257(_box_col_values)
#         1    0.000    0.000    0.002    0.002 frame.py:6862(sort_values)
#         3    0.000    0.000    0.001    0.000 frame.py:609(__init__)
#        12    0.000    0.000    0.000    0.000 dtypes.py:334(_finalize)
#         4    0.000    0.000    0.000    0.000 managers.py:1445(_insert_update_mgr_locs)
#        11    0.000    0.000    0.000    0.000 re.py:288(_compile)
#         4    0.000    0.000    0.000    0.000 numeric.py:1411(moveaxis)
#         9    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 base.py:7396(_maybe_cast_data_without_dtype)
#         6    0.000    0.000    0.000    0.000 _dtype.py:344(_name_get)
#         8    0.000    0.000    0.000    0.000 numeric.py:1348(normalize_axis_tuple)
#        11    0.000    0.000    0.000    0.000 numeric.py:290(full)
#        17    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:33(seterr)
#         4    0.000    0.000    0.000    0.000 numeric.py:132(_ensure_array)
#        17    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         3    0.000    0.000    0.000    0.000 cast.py:1763(construct_1d_object_array_from_listlike)
#         3    0.000    0.000    0.000    0.000 generic.py:1799(_get_label_or_level_values)
#         2    0.000    0.000    0.001    0.000 construction.py:423(dict_to_mgr)
#        16    0.000    0.000    0.000    0.000 common.py:1246(is_float_dtype)
#         3    0.000    0.000    0.000    0.000 algorithms.py:287(_check_object_for_strings)
#        17    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         9    0.000    0.000    0.000    0.000 config.py:116(_get_single_key)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int8}
#        30    0.000    0.000    0.000    0.000 construction.py:399(extract_array)
#         3    0.000    0.000    0.000    0.000 _asarray.py:31(require)
#         2    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#        24    0.000    0.000    0.000    0.000 common.py:1487(is_ea_or_datetimelike_dtype)
#        15    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#         6    0.000    0.000    0.000    0.000 categorical.py:764(codes)
#         1    0.000    0.000    0.000    0.000 {method 'get_labels_groupby' of 'pandas._libs.hashtable.Int64HashTable' objects}
#        17    0.000    0.000    0.000    0.000 base.py:7372(maybe_extract_name)
#         1    0.000    0.000    0.050    0.050 <string>:1(<module>)
#        13    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#        20    0.000    0.000    0.000    0.000 construction.py:676(_sanitize_ndim)
#         3    0.000    0.000    0.000    0.000 frame.py:4139(_set_item_mgr)
#        50    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         6    0.000    0.000    0.000    0.000 algorithms.py:197(_reconstruct_data)
#         2    0.000    0.000    0.000    0.000 construction.py:588(_homogenize)
#         9    0.000    0.000    0.000    0.000 config.py:597(_get_root)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         4    0.000    0.000    0.000    0.000 shape_base.py:299(hstack)
#         5    0.000    0.000    0.000    0.000 take.py:57(take_nd)
#         4    0.000    0.000    0.000    0.000 shape_base.py:23(atleast_1d)
#         4    0.000    0.000    0.000    0.000 frame.py:4892(_sanitize_column)
#        13    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        13    0.000    0.000    0.000    0.000 base.py:286(is_dtype)
#         3    0.000    0.000    0.000    0.000 frame.py:3955(__setitem__)
#        25    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         2    0.000    0.000    0.000    0.000 managers.py:2182(create_block_manager_from_column_arrays)
#         1    0.000    0.000    0.000    0.000 sorting.py:704(_reorder_by_uniques)
#        17    0.000    0.000    0.000    0.000 cast.py:1422(sanitize_to_nanoseconds)
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.groupsort_indexer}
#         5    0.000    0.000    0.000    0.000 take.py:554(_take_preprocess_indexer_and_fill_value)
#         9    0.000    0.000    0.000    0.000 base.py:5116(_get_engine_target)
#         4    0.000    0.000    0.000    0.000 managers.py:1455(_insert_update_blklocs_and_blknos)
#         3    0.000    0.000    0.000    0.000 algorithms.py:117(_ensure_data)
#         4    0.000    0.000    0.000    0.000 series.py:3194(_construct_result)
#         9    0.000    0.000    0.000    0.000 config.py:134(_get_option)
#        18    0.000    0.000    0.000    0.000 config.py:611(_get_deprecated_option)
#         1    0.000    0.000    0.000    0.000 construction.py:627(_extract_index)
#        22    0.000    0.000    0.000    0.000 common.py:156(<lambda>)
#         4    0.000    0.000    0.000    0.000 managers.py:2398(_fast_count_smallints)
#         1    0.000    0.000    0.000    0.000 sorting.py:639(get_group_index_sorter)
#         5    0.000    0.000    0.000    0.000 missing.py:191(_isna)
#         6    0.000    0.000    0.000    0.000 function_base.py:5444(append)
#        12    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(concatenate)
#         3    0.000    0.000    0.000    0.000 dtypes.py:544(update_dtype)
#         4    0.000    0.000    0.000    0.000 array_ops.py:136(_na_arithmetic_op)
#         6    0.000    0.000    0.000    0.000 numerictypes.py:356(issubdtype)
#         3    0.000    0.000    0.000    0.000 generic.py:1699(_is_label_reference)
#         1    0.000    0.000    0.000    0.000 missing.py:268(_isna_array)
#         3    0.000    0.000    0.000    0.000 base.py:54(shape)
#        20    0.000    0.000    0.000    0.000 construction.py:713(_sanitize_str_dtypes)
#        25    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#        12    0.000    0.000    0.000    0.000 _methods.py:55(_any)
#         6    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#         1    0.000    0.000    0.000    0.000 base.py:1168(take)
#         6    0.000    0.000    0.000    0.000 common.py:585(is_dtype_equal)
#         1    0.000    0.000    0.000    0.000 arraylike.py:244(array_ufunc)
#         1    0.000    0.000    0.000    0.000 sorting.py:682(compress_group_index)
#         2    0.000    0.000    0.000    0.000 construction.py:100(arrays_to_mgr)
#        12    0.000    0.000    0.000    0.000 dtypes.py:185(__init__)
#         6    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#        20    0.000    0.000    0.000    0.000 construction.py:733(_maybe_repeat)
#         9    0.000    0.000    0.000    0.000 common.py:790(is_unsigned_integer_dtype)
#         4    0.000    0.000    0.000    0.000 blocks.py:2266(ensure_block_shape)
#         8    0.000    0.000    0.000    0.000 common.py:303(maybe_iterable_to_list)
#         4    0.000    0.000    0.000    0.000 common.py:57(new_method)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op}
#         3    0.000    0.000    0.000    0.000 generic.py:1754(_check_label_or_level_ambiguity)
#        15    0.000    0.000    0.000    0.000 common.py:566(require_length_match)
#        11    0.000    0.000    0.000    0.000 series.py:1267(_set_as_cached)
#         5    0.000    0.000    0.000    0.000 series.py:565(_set_axis)
#         4    0.000    0.000    0.000    0.000 array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 managers.py:2023(getitem_mgr)
#         4    0.000    0.000    0.000    0.000 series.py:6257(_arith_method)
#        17    0.000    0.000    0.000    0.000 managers.py:172(blknos)
#        13    0.000    0.000    0.000    0.000 base.py:7277(ensure_index)
#         5    0.000    0.000    0.000    0.000 cast.py:527(maybe_promote)
#         1    0.000    0.000    0.000    0.000 common.py:463(is_interval_dtype)
#        12    0.000    0.000    0.000    0.000 numerictypes.py:282(issubclass_)
#         1    0.000    0.000    0.000    0.000 managers.py:944(take)
#        21    0.000    0.000    0.000    0.000 common.py:146(classes)
#         3    0.000    0.000    0.000    0.000 base.py:2824(hasnans)
#        65    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#         2    0.000    0.000    0.000    0.000 blocks.py:861(take_nd)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         6    0.000    0.000    0.000    0.000 warnings.py:165(simplefilter)
#         3    0.000    0.000    0.000    0.000 _asarray.py:112(<setcomp>)
#         3    0.000    0.000    0.000    0.000 dtypes.py:208(_from_values_or_dtype)
#         6    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        21    0.000    0.000    0.000    0.000 common.py:148(<lambda>)
#         1    0.000    0.000    0.000    0.000 managers.py:689(reindex_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:4215(_convert_slice_indexer)
#        11    0.000    0.000    0.000    0.000 re.py:249(compile)
#        13    0.000    0.000    0.000    0.000 base.py:870(_reset_identity)
#         9    0.000    0.000    0.000    0.000 common.py:736(is_signed_integer_dtype)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(hstack)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:1781(ravel)
#         8    0.000    0.000    0.000    0.000 managers.py:2237(_grouping_func)
#         8    0.000    0.000    0.000    0.000 numeric.py:1398(<listcomp>)
#         1    0.000    0.000    0.000    0.000 sorting.py:290(indexer_from_factorized)
#        12    0.000    0.000    0.000    0.000 dtypes.py:488(validate_ordered)
#        25    0.000    0.000    0.000    0.000 base.py:5090(_values)
#         4    0.000    0.000    0.000    0.000 array_ops.py:445(maybe_prepare_scalar_for_op)
#         1    0.000    0.000    0.000    0.000 managers.py:1860(<listcomp>)
#         9    0.000    0.000    0.000    0.000 config.py:262(__call__)
#         4    0.000    0.000    0.000    0.000 managers.py:1934(from_array)
#         3    0.000    0.000    0.000    0.000 generic.py:3908(xs)
#         5    0.000    0.000    0.000    0.000 common.py:162(is_object_dtype)
#         4    0.000    0.000    0.000    0.000 base.py:5204(_validate_fill_value)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         3    0.000    0.000    0.000    0.000 indexing.py:2488(convert_to_index_sliceable)
#         1    0.000    0.000    0.000    0.000 numeric.py:77(zeros_like)
#         3    0.000    0.000    0.000    0.000 frame.py:4164(_set_item)
#         6    0.000    0.000    0.000    0.000 generic.py:1726(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.truediv}
#         9    0.000    0.000    0.000    0.000 config.py:579(_select_options)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         9    0.000    0.000    0.000    0.000 config.py:650(_warn_if_deprecated)
#         5    0.000    0.000    0.000    0.000 take.py:326(_get_take_nd_function)
#        21    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#        18    0.000    0.000    0.000    0.000 managers.py:1435(<genexpr>)
#         4    0.000    0.000    0.000    0.000 common.py:684(is_integer_dtype)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(where)
#         3    0.000    0.000    0.000    0.000 sorting.py:545(ensure_key_mapped)
#         4    0.000    0.000    0.000    0.000 blocks.py:2161(new_block_2d)
#         4    0.000    0.000    0.000    0.000 inference.py:266(is_dict_like)
#         4    0.000    0.000    0.000    0.000 missing.py:140(dispatch_fill_zeros)
#         4    0.000    0.000    0.000    0.000 missing.py:699(is_valid_na_for_dtype)
#        22    0.000    0.000    0.000    0.000 common.py:151(classes_and_not_datetimelike)
#        51    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         3    0.000    0.000    0.000    0.000 algorithms.py:269(_get_hashtable_algo)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(insert)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis0_float64_float64}
#         4    0.000    0.000    0.000    0.000 expressions.py:64(_evaluate_standard)
#         6    0.000    0.000    0.000    0.000 common.py:501(is_categorical_dtype)
#        21    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:430(__enter__)
#         2    0.000    0.000    0.000    0.000 common.py:99(_maybe_match_name)
#         2    0.000    0.000    0.000    0.000 managers.py:1854(_consolidate_check)
#         1    0.000    0.000    0.000    0.000 numeric.py:221(_convert_slice_indexer)
#         5    0.000    0.000    0.000    0.000 base.py:58(_validate_set_axis)
#        13    0.000    0.000    0.000    0.000 inference.py:292(<genexpr>)
#         2    0.000    0.000    0.000    0.000 construction.py:481(<listcomp>)
#        17    0.000    0.000    0.000    0.000 managers.py:188(blklocs)
#         1    0.000    0.000    0.000    0.000 arraylike.py:182(_maybe_fallback)
#         3    0.000    0.000    0.000    0.000 cast.py:1004(coerce_indexer_dtype)
#         4    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         8    0.000    0.000    0.000    0.000 series.py:846(__array__)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ravel)
#         1    0.000    0.000    0.000    0.000 utils.py:243(maybe_convert_indices)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#        13    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1026d2ff8}
#         5    0.000    0.000    0.000    0.000 construction.py:861(is_empty_data)
#         4    0.000    0.000    0.000    0.000 shape_base.py:207(_arrays_for_stack_dispatcher)
#         1    0.000    0.000    0.000    0.000 managers.py:751(<listcomp>)
#         4    0.000    0.000    0.000    0.000 expressions.py:225(evaluate)
#         4    0.000    0.000    0.000    0.000 __init__.py:152(align_method_SERIES)
#         3    0.000    0.000    0.000    0.000 base.py:2281(_can_hold_na)
#         9    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 managers.py:1846(is_consolidated)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_int64_int64}
#         9    0.000    0.000    0.000    0.000 config.py:638(_translate_key)
#         3    0.000    0.000    0.000    0.000 generic.py:4137(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 base.py:742(__iter__)
#         9    0.000    0.000    0.000    0.000 base.py:56(<genexpr>)
#         5    0.000    0.000    0.000    0.000 managers.py:228(set_axis)
#        11    0.000    0.000    0.000    0.000 enum.py:801(value)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:435(__exit__)
#         2    0.000    0.000    0.000    0.000 blocks.py:236(make_block_same_class)
#         3    0.000    0.000    0.000    0.000 algorithms.py:855(resolve_na_sentinel)
#         1    0.000    0.000    0.000    0.000 frame.py:4756(insert)
#         1    0.000    0.000    0.000    0.000 series.py:1009(_get_with)
#         1    0.000    0.000    0.000    0.000 cast.py:120(maybe_convert_platform)
#         6    0.000    0.000    0.000    0.000 frame.py:857(axes)
#         2    0.000    0.000    0.000    0.000 missing.py:645(na_value_for_dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.sub}
#         4    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         4    0.000    0.000    0.000    0.000 common.py:1154(needs_i8_conversion)
#         1    0.000    0.000    0.002    0.002 _decorators.py:323(wrapper)
#         4    0.000    0.000    0.000    0.000 common.py:77(get_op_result_name)
#         3    0.000    0.000    0.000    0.000 base.py:1820(_get_names)
#         3    0.000    0.000    0.000    0.000 common.py:1433(is_extension_array_dtype)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_1d)
#         1    0.000    0.000    0.000    0.000 frame.py:6894(<listcomp>)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(moveaxis)
#         6    0.000    0.000    0.000    0.000 base.py:413(_engine_type)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(bincount)
#         6    0.000    0.000    0.000    0.000 generic.py:640(_info_axis)
#         1    0.000    0.000    0.000    0.000 series.py:1068(_get_values)
#         4    0.000    0.000    0.000    0.000 shape_base.py:218(_vhstack_dispatcher)
#        16    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         4    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#        17    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         1    0.000    0.000    0.000    0.000 generic.py:2109(__array_ufunc__)
#         6    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         3    0.000    0.000    0.000    0.000 common.py:531(convert_to_list_like)
#         4    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 missing.py:108(isna)
#         1    0.000    0.000    0.000    0.000 range.py:173(_simple_new)
#        13    0.000    0.000    0.000    0.000 multiarray.py:1079(copyto)
#         1    0.000    0.000    0.000    0.000 range.py:195(_data)
#         4    0.000    0.000    0.000    0.000 frame.py:4234(_ensure_valid_index)
#        16    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2955(prod)
#         1    0.000    0.000    0.000    0.000 sorting.py:144(_int64_cut_off)
#         3    0.000    0.000    0.000    0.000 categorical.py:715(categories)
#         1    0.000    0.000    0.000    0.000 inference.py:363(is_sequence)
#         4    0.000    0.000    0.000    0.000 array_ops.py:514(_bool_arith_check)
#         1    0.000    0.000    0.000    0.000 sorting.py:157(<listcomp>)
#         9    0.000    0.000    0.000    0.000 base.py:986(dtype)
#         1    0.000    0.000    0.000    0.000 managers.py:1061(from_blocks)
#         4    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 managers.py:2058(dtype)
#         1    0.000    0.000    0.000    0.000 api.py:384(default_index)
#         6    0.000    0.000    0.000    0.000 base.py:574(_ensure_array)
#        15    0.000    0.000    0.000    0.000 dtypes.py:577(categories)
#         1    0.000    0.000    0.000    0.000 roperator.py:14(rsub)
#         6    0.000    0.000    0.000    0.000 range.py:946(__len__)
#         6    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 construction.py:482(<listcomp>)
#        10    0.000    0.000    0.000    0.000 multiarray.py:152(concatenate)
#         4    0.000    0.000    0.000    0.000 dispatch.py:13(should_extension_dispatch)
#         2    0.000    0.000    0.000    0.000 managers.py:1864(_consolidate_inplace)
#         6    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.050    0.050 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.internals.update_blklocs_and_blknos}
#         8    0.000    0.000    0.000    0.000 base.py:1734(name)
#         1    0.000    0.000    0.000    0.000 algorithms.py:1484(take)
#         2    0.000    0.000    0.000    0.000 common.py:1751(pandas_dtype)
#        10    0.000    0.000    0.000    0.000 base.py:241(disallow_kwargs)
#         3    0.000    0.000    0.000    0.000 algorithms.py:235(_ensure_arraylike)
#         1    0.000    0.000    0.000    0.000 numeric.py:150(ones)
#         1    0.000    0.000    0.000    0.000 _validators.py:457(<listcomp>)
#         5    0.000    0.000    0.000    0.000 blocks.py:500(dtype)
#         3    0.000    0.000    0.000    0.000 algorithms.py:905(_re_wrap_factorize)
#         1    0.000    0.000    0.000    0.000 base.py:2801(_na_value)
#         2    0.000    0.000    0.000    0.000 construction.py:488(<listcomp>)
#         1    0.000    0.000    0.000    0.000 arraylike.py:100(__add__)
#         1    0.000    0.000    0.000    0.000 dtypes.py:1247(is_dtype)
#        15    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 base.py:5464(equals)
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         9    0.000    0.000    0.000    0.000 dtypes.py:584(ordered)
#        10    0.000    0.000    0.000    0.000 base.py:324(ndim)
#         4    0.000    0.000    0.000    0.000 base.py:555(<genexpr>)
#         4    0.000    0.000    0.000    0.000 cast.py:1931(np_can_hold_element)
#         1    0.000    0.000    0.000    0.000 _validators.py:449(validate_ascending)
#         4    0.000    0.000    0.000    0.000 numeric.py:192(_ensure_dtype)
#         3    0.000    0.000    0.000    0.000 frame.py:1498(__len__)
#         2    0.000    0.000    0.000    0.000 blocks.py:200(fill_value)
#         3    0.000    0.000    0.000    0.000 categorical.py:475(dtype)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(putmask)
#         2    0.000    0.000    0.000    0.000 construction.py:231(mgr_to_mgr)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(prod)
#         4    0.000    0.000    0.000    0.000 numeric.py:181(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 {method 'put' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 typing.py:993(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 frame.py:12012(_reindex_for_setitem)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(zeros_like)
#         1    0.000    0.000    0.000    0.000 typing.py:1154(__subclasscheck__)
#         4    0.000    0.000    0.000    0.000 numeric.py:1473(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:2752(_is_all_dates)
#         3    0.000    0.000    0.000    0.000 generic.py:1835(<listcomp>)
#         2    0.000    0.000    0.000    0.000 numeric.py:381(_engine_type)
#         4    0.000    0.000    0.000    0.000 base.py:2783(_is_multi)
#         1    0.000    0.000    0.000    0.000 generic.py:570(_get_block_manager_axis)
#         3    0.000    0.000    0.000    0.000 multiarray.py:345(where)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 sorting.py:340(<listcomp>)
#         1    0.000    0.000    0.000    0.000 series.py:596(dtype)
#         3    0.000    0.000    0.000    0.000 arraylike.py:195(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(empty_like)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:426(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:874(shape)
#         6    0.000    0.000    0.000    0.000 generic.py:1721(<genexpr>)
#         6    0.000    0.000    0.000    0.000 categorical.py:2056(_codes)
#         3    0.000    0.000    0.000    0.000 base.py:6582(_validate_indexer)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         8    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 base.py:2457(is_integer)
#         3    0.000    0.000    0.000    0.000 managers.py:997(__init__)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:1777(_ravel_dispatcher)
#         1    0.000    0.000    0.000    0.000 range.py:353(dtype)
#         6    0.000    0.000    0.000    0.000 function_base.py:5440(_append_dispatcher)
#         5    0.000    0.000    0.000    0.000 series.py:546(_constructor)
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.is_matching_na}
#         1    0.000    0.000    0.000    0.000 common.py:537(is_string_or_object_np_dtype)
#         1    0.000    0.000    0.000    0.000 series.py:961(_slice)
#         3    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 numeric.py:1407(_moveaxis_dispatcher)
#         4    0.000    0.000    0.000    0.000 function_base.py:5246(_insert_dispatcher)
#         4    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 multiarray.py:891(bincount)
#         1    0.000    0.000    0.000    0.000 base.py:2811(_isnan)
#         1    0.000    0.000    0.000    0.000 numeric.py:115(inferred_type)
#         3    0.000    0.000    0.000    0.000 base.py:4233(is_int)
#         1    0.000    0.000    0.000    0.000 arraylike.py:124(__truediv__)
#         1    0.000    0.000    0.000    0.000 arraylike.py:108(__sub__)
#         1    0.000    0.000    0.000    0.000 arraylike.py:112(__rsub__)
#         1    0.000    0.000    0.000    0.000 blocks.py:836(_slice)
#         3    0.000    0.000    0.000    0.000 base.py:839(is_)
#         3    0.000    0.000    0.000    0.000 arraylike.py:196(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 numeric.py:418(_engine_type)
#         4    0.000    0.000    0.000    0.000 shape_base.py:19(_atleast_1d_dispatcher)
#         1    0.000    0.000    0.000    0.000 range.py:270(stop)
#         1    0.000    0.000    0.000    0.000 base.py:1194(_maybe_disallow_fill)
#         1    0.000    0.000    0.000    0.000 frame.py:600(_constructor)
#         3    0.000    0.000    0.000    0.000 generic.py:1775(<genexpr>)
#         1    0.000    0.000    0.000    0.000 multiarray.py:1130(putmask)
#         1    0.000    0.000    0.000    0.000 range.py:247(start)
#         1    0.000    0.000    0.000    0.000 arraylike.py:421(_standardize_out_kwarg)
#         1    0.000    0.000    0.000    0.000 range.py:293(step)
#         1    0.000    0.000    0.000    0.000 multiarray.py:84(empty_like)
#         1    0.000    0.000    0.000    0.000 numeric.py:73(_zeros_like_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2950(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 managers.py:2054(index)
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 range.py:189(_constructor)
#         1    0.000    0.000    0.000    0.000 numeric.py:216(_should_fallback_to_positional)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}

# %%
# %%timeit
[coxdev_(eta, weight) for _ in range(20)]

# %%
# %%prun
dev_, G_, H_ = coxdev_(eta, 
                       weight)
